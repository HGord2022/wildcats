# %%
from flowjax.train import fit_to_data
from flowjax.train.losses import ContrastiveLoss
from flowjax.flows import masked_autoregressive_flow as MaskedAutoregressiveFlow
from flowjax.train.losses import MaximumLikelihoodLoss
from flowjax.distributions import Normal, Laplace
import flowjax.bijections as bij
import jax.numpy as jnp
import jax.random as jr
import matplotlib.pyplot as plt
import equinox as eqx
import numpy as np
from sklearn.preprocessing import StandardScaler
from jax import vmap
import pandas as pd
import json
import pickle

# %%
#observed data
filename = "../../simulation/observed_data/observed_stats.csv"
x_o = pd.read_csv(filename)
#simulated data
filename2 = "../../simulation/output/round_1_point/summary_stats_r1.csv"
x = pd.read_csv(filename2)
#params for simulations
filename3 = "../../simulation/output/round_1_point/thetas_r1.csv"
theta = jnp.array(np.genfromtxt(filename3, delimiter=',', dtype=float))

# %%
to_drop = [#correlation >0.99
    "y1_domestic",
    "y1_scot",
    "y1_captive",
    "y1_eu",
    "y1_lyb",
    "y3_domestic_captive_lyb",
    "divergence_domestic_eu",
    "y3_domestic_scot_lyb",
    "y3_domestic_eu_lyb",
    "divergence_captive_lyb",
    "segregating_sites_lyb",
    "segregating_sites_eu",
    "divergence_scot_lyb",
    "f4_domestic_scot_captive_lyb",
    "f4_domestic_captive_eu_lyb",
    "f4_domestic_scot_eu_lyb",
    "diversity_domestic",
    "y3_domestic_scot_captive",
    "y3_scot_captive_eu",
    "f2_domestic_eu",
    "y2_domestic_lyb",
    "y3_scot_captive_lyb",
    "divergence_captive_eu",
    "pc1_dist_domestic_eu"]

# %%
to_drop = [#correlation >0.99
    "y1_domestic",
    "y1_scot",
    "y1_captive",
    "y1_eu",
    "y1_lyb",
    "y3_domestic_captive_lyb",
    "divergence_domestic_eu",
    "y3_domestic_scot_lyb",
    "y3_domestic_eu_lyb",
    "divergence_captive_lyb",
    "segregating_sites_lyb",
    "segregating_sites_eu",
    "divergence_scot_lyb",
    "f4_domestic_scot_captive_lyb",
    "f4_domestic_captive_eu_lyb",
    "f4_domestic_scot_eu_lyb",
    "diversity_domestic",
    "y3_domestic_scot_captive",
    "y3_scot_captive_eu",
    "f2_domestic_eu",
    "y2_domestic_lyb",
    "y3_scot_captive_lyb",
    "divergence_captive_eu",
    "pc1_dist_domestic_eu",
    # outlier noise model method r1 (>1)
    'tajimas_d_eu',
    'relatedness_domestic_lyb',
    'pc1_iqr_domestic',
    'pc1_iqr_eu',
    'pc1_iqr_lyb',
    'pc2_iqr_domestic',
    'pc2_iqr_lyb',
    # outlier noise model method r2 (>0.8)
    'relatedness_captive_lyb',
    'pc1_median_eu',
    'pc2_dist_domestic_lyb']

{'tajimas_d_eu': 2.924356698989868,
 'relatedness_domestic_lyb': 1.0065529346466064,
 'pc1_median_eu': 0.8109098672866821,
 'pc2_median_lyb': 0.8232396245002747,
 'pc1_iqr_domestic': 2.226839542388916,
 'pc1_iqr_eu': 5.434721946716309,
 'pc1_iqr_lyb': 2.033045768737793,
 'pc2_iqr_domestic': 2.554408073425293,
 'pc2_iqr_lyb': 9.832843780517578}

{'tajimas_d_eu': 2.9451754093170166,
 'relatedness_domestic_lyb': 1.0059717893600464,
 'pc1_median_eu': 0.8189070820808411,
 'pc2_median_lyb': 0.8371109962463379,
 'pc1_iqr_domestic': 2.2041139602661133,
 'pc1_iqr_eu': 5.41973352432251,
 'pc1_iqr_lyb': 1.970677137374878,
 'pc2_iqr_domestic': 2.5619406700134277,
 'pc2_iqr_lyb': 9.789983749389648}

# %%
# 15/9/25

to_drop = [ # >99% correlated
  "y3_domestic_scot_lyb",
  "y3_domestic_captive_lyb",
  "diversity_domestic",
  "f3_domestic_scot_captive",
  "f3_domestic_scot_eu",
  "f3_domestic_captive_eu",
  "y3_domestic_eu_lyb",
  "divergence_domestic_eu",
  "divergence_domestic_captive",
  "divergence_scot_lyb",
  "segregating_sites_eu",
  "diversity_lyb",
  "pc2_median_lyb",
  "tajimas_d_eu",
]

# %%
combined_x = pd.concat([x, x_o], ignore_index=True)
combined_x = combined_x.drop(columns=to_drop)
stats = combined_x.columns
combined_x = combined_x.to_numpy(dtype=np.float32)
np.shape(combined_x)
# Out:
# (10001, 121)

# %%
#normalise data
x_scaler = StandardScaler()
print("combined_x shape", np.shape(combined_x))
combined_x_t = x_scaler.fit_transform(combined_x)
x_t = np.float32(combined_x_t[0:10000])
x_o_t = np.float32(combined_x_t[10000])
x_o_t = np.reshape(x_o_t, (1,-1))
print("x_t shape", np.shape(x_t))
print("x_o_t shape", np.shape(x_o_t))
# Out:
# combined_x shape (10001, 121)
# x_t shape (10000, 121)
# x_o_t shape (1, 121)

# %%
theta = theta[1:10001]
log_theta = jnp.log(theta)
theta_scaler = StandardScaler()
theta_t = theta_scaler.fit_transform(log_theta)
print("theta_t shape", np.shape(theta_t))
# Out:
# theta_t shape (10000, 14)

# %%
key, subkey = jr.split(jr.PRNGKey(2))
#define prior
n_summaries = np.shape(x_o_t)[1]

unbounded_prior = Normal(jnp.zeros((n_summaries,)))

# %%
flow = MaskedAutoregressiveFlow(
    subkey,
    base_dist=Normal(jnp.zeros((n_summaries,))),
)

# %%
import optax
optimizer = optax.chain(
        optax.clip_by_global_norm(1),
        optax.adam(1e-4),
    )

# %%
loss_fn = MaximumLikelihoodLoss()

# %%
fitted_flow, losses_r = fit_to_data(
    key=subkey,
    dist=flow,
    loss_fn=loss_fn,
    x=x_t,
    optimizer = optimizer,
    max_epochs=1500,
    batch_size = 200,
    max_patience = 20
)
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
#  58%|█████▊    | 872/1500 [03:34<02:34,  4.06it/s, train=inf, val=inf]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 fitted_flow, losses_r = fit_to_data(
#       2     key=subkey,
#       3     dist=flow,
#       4     loss_fn=loss_fn,
#       5     x=x_t,
#       6     optimizer = optimizer,
#       7     max_epochs=1500,
#       8     batch_size = 200,
#       9     max_patience = 20
#      10 )
#
# File /opt/miniconda3/envs/wildcats/lib/python3.11/site-packages/flowjax/train/loops.py:157, in fit_to_data(key, dist, x, condition, loss_fn, learning_rate, optimizer, max_epochs, max_patience, batch_size, val_prop, return_best, show_progress)
#     155 for batch in zip(*get_batches(train_data, batch_size), strict=True):
#     156     key, subkey = jr.split(key)
# --> 157     params, opt_state, loss_i = step(
#     158         params,
#     159         static,
#     160         *batch,
#     161         optimizer=optimizer,
#     162         opt_state=opt_state,
#     163         loss_fn=loss_fn,
#     164         key=subkey,
#     165     )
#     166     batch_losses.append(loss_i)
#     167 losses["train"].append((sum(batch_losses) / len(batch_losses)).item())
#
#     [... skipping hidden 3 frame]
#
# File /opt/miniconda3/envs/wildcats/lib/python3.11/site-packages/equinox/_module.py:792, in _unflatten_module(cls, aux, dynamic_field_values)
#     782     aux = _FlattenedData(
#     783         tuple(dynamic_field_names),
#     784         tuple(static_field_names),
#    (...)
#     787         tuple(wrapper_field_values),
#     788     )
#     789     return tuple(dynamic_field_values), aux
# --> 792 def _unflatten_module(cls: type["Module"], aux: _FlattenedData, dynamic_field_values):
#     793     # This doesn't go via `__init__`. A user may have done something nontrivial there,
#     794     # and the field values may be dummy values as used in various places throughout JAX.
#     795     # See also
#     796     # https://jax.readthedocs.io/en/latest/pytrees.html#custom-pytrees-and-initialization,
#     797     # which was (I believe) inspired by Equinox's approach here.
#     798     module = object.__new__(cls)
#     799     for name, value in zip(aux.dynamic_field_names, dynamic_field_values):
#
# KeyboardInterrupt:

# %%
for k, v in losses_r.items():
    plt.plot(v, label=k)
plt.legend()

# %%
posterior = fitted_flow
posterior.log_prob(x_o_t)
# Out:
# Array([-inf], dtype=float32)

# %%
Array([-2893.844], dtype=float32)

# %%
Array([-6476.0303], dtype=float32)

# %% [markdown]
# #### Stat + error method

# %%
from flowjax.experimental.numpyro import sample


def model(obs=None):  # This is a numpyro probabilistic program
    noise_prior = Laplace(jnp.zeros((n_summaries, )), 1)
    error = sample("noise", noise_prior)
    denoised_obs = obs - error
    sample("x", flow, obs=denoised_obs)

# %%
from numpyro.infer import MCMC, NUTS
mcmc = MCMC(NUTS(model), num_warmup=1000, num_samples=5000)
key, subkey = jr.split(key)
mcmc.run(subkey, obs=x_o_t)
# Out:
# /var/folders/ty/5bvjyd1n4dx2ymnhbn1s9579brngf7/T/ipykernel_3864/801673538.py:4: UserWarning: Site x: Out-of-support values provided to log prob method. The value argument should be within the support.
#   mcmc.run(subkey, obs=x_o_t)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 4
#       2 mcmc = MCMC(NUTS(model), num_warmup=1000, num_samples=5000)
#       3 key, subkey = jr.split(key)
# ----> 4 mcmc.run(subkey, obs=x_o_t)
#
# File /opt/miniconda3/envs/wildcats/lib/python3.11/site-packages/numpyro/infer/mcmc.py:692, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     690 map_args = (rng_key, init_state, init_params)
#     691 if self.num_chains == 1:
# --> 692     states_flat, last_state = partial_map_fn(map_args)
#     693     states = jax.tree.map(lambda x: x[jnp.newaxis, ...], states_flat)
#     694 else:
#
# File /opt/miniconda3/envs/wildcats/lib/python3.11/site-packages/numpyro/infer/mcmc.py:459, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields, remove_sites)
#     457 # Check if _sample_fn is None, then we need to initialize the sampler.
#     458 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 459     new_init_state = self.sampler.init(
#     460         rng_key,
#     461         self.num_warmup,
#     462         init_params,
#     463         model_args=args,
#     464         model_kwargs=kwargs,
#     465     )
#     466     init_state = new_init_state if init_state is None else init_state
#     467 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File /opt/miniconda3/envs/wildcats/lib/python3.11/site-packages/numpyro/infer/hmc.py:749, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     744 # vectorized
#     745 else:
#     746     rng_key, rng_key_init_model = jnp.swapaxes(
#     747         vmap(random.split)(rng_key), 0, 1
#     748     )
# --> 749 init_params = self._init_state(
#     750     rng_key_init_model, model_args, model_kwargs, init_params
#     751 )
#     752 if self._potential_fn and init_params is None:
#     753     raise ValueError(
#     754         "Valid value of `init_params` must be provided with" " `potential_fn`."
#     755     )
#
# File /opt/miniconda3/envs/wildcats/lib/python3.11/site-packages/numpyro/infer/hmc.py:693, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     686 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     687     if self._model is not None:
#     688         (
#     689             new_init_params,
#     690             potential_fn,
#     691             postprocess_fn,
#     692             model_trace,
# --> 693         ) = initialize_model(
#     694             rng_key,
#     695             self._model,
#     696             dynamic_args=True,
#     697             init_strategy=self._init_strategy,
#     698             model_args=model_args,
#     699             model_kwargs=model_kwargs,
#     700             forward_mode_differentiation=self._forward_mode_differentiation,
#     701         )
#     702         if init_params is None:
#     703             init_params = new_init_params
#
# File /opt/miniconda3/envs/wildcats/lib/python3.11/site-packages/numpyro/infer/util.py:758, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     745                             w.message.args = (
#     746                                 "Site {}: {}".format(
#     747                                     site["name"], w.message.args[0]
#     748                                 ),
#     749                             ) + w.message.args[1:]
#     750                             warnings.showwarning(
#     751                                 w.message,
#     752                                 w.category,
#    (...)
#     756                                 line=w.line,
#     757                             )
# --> 758         raise RuntimeError(
#     759             "Cannot find valid initial parameters. Please check your model again."
#     760         )
#     761 return ModelInfo(
#     762     ParamInfo(init_params, pe, grad), potential_fn, postprocess_fn, model_trace
#     763 )
#
# RuntimeError: Cannot find valid initial parameters. Please check your model again.

# %%
inferred_errors = mcmc.get_samples()["noise"]

mean_abs_error = jnp.abs(inferred_errors).mean(axis=0)
plt.bar(x=[f"s{i}" for i in range(n_summaries)], height=mean_abs_error)
plt.ylabel("mean absolute noise (from posterior over noise)")
plt.xlabel("summary statistics")
plt.xticks([])
# Out:
# ([], [])

# %%
error = mean_abs_error.tolist()
error_dict = dict(zip(stats, error))

# %%
misspecified = {k: v for k, v in error_dict.items() if v > 0.8
               }
misspecified
# Out:
# {'tajimas_d_eu': 2.9451754093170166,
#  'relatedness_domestic_lyb': 1.0059717893600464,
#  'pc1_median_eu': 0.8189070820808411,
#  'pc2_median_lyb': 0.8371109962463379,
#  'pc1_iqr_domestic': 2.2041139602661133,
#  'pc1_iqr_eu': 5.41973352432251,
#  'pc1_iqr_lyb': 1.970677137374878,
#  'pc2_iqr_domestic': 2.5619406700134277,
#  'pc2_iqr_lyb': 9.789983749389648}

# %%
misspecified.keys()
# Out:
# dict_keys(['relatedness_captive_lyb', 'pc1_median_eu', 'pc2_dist_domestic_lyb'])

# %%
{'tajimas_d_eu': 2.924356698989868,
 'relatedness_domestic_lyb': 1.0065529346466064,
 'pc1_iqr_domestic': 2.226839542388916,
 'pc1_iqr_eu': 5.434721946716309,
 'pc1_iqr_lyb': 2.033045768737793,
 'pc2_iqr_domestic': 2.554408073425293,
 'pc2_iqr_lyb': 9.832843780517578}

# %%
# iter 1.1 (1)
{'tajimas_d_eu': 2.7469213008880615,
 'pc1_iqr_domestic': 2.56209135055542,
 'pc1_iqr_eu': 4.763359069824219,
 'pc1_iqr_lyb': 2.1821603775024414,
 'pc2_iqr_domestic': 2.159055709838867,
 'pc2_iqr_lyb': 9.031184196472168}

# %%
# iter 1.2 (0.7)
{'relatedness_domestic_lyb': 0.823789656162262,
 'fst_domestic_lyb': 0.8101553320884705}

# %%
# iter 1
{'relatedness_captive_lyb': 1.1016290187835693,
 'fst_scot_lyb': 1.277429461479187,
 'pc2_dist_domestic_lyb': 1.1340640783309937,
 'pc2_dist_scot_lyb': 1.3770017623901367}

# %%
# iter 2
{'relatedness_scot_lyb': 1.4759607315063477}

# %%
misspecified_stats
 
pc1_iqr_domestic
pc1_iqr_eu
pc1_iqr_lyb
pc2_iqr_domestic
pc2_iqr_lyb
